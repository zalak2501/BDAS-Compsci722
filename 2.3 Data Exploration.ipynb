# %% [markdown]
# Using Pandas and Matplotlib for getting better visuals-

# %%
#######  DATA EXPLORATION  #######

# Full-time employment dataset

import pandas as pd

#using index_col to index data through Country and not any arbitraty numbers like 0,1,2..

fte=pd.read_csv('My datasets/full-time_employ_rate.csv',index_col='Country')
fte.head()
# Out:
#              Sex  1995_fte  1996_fte  1997_fte  1998_fte  1999_fte  2000_fte  \
# Country
# Australia    Men       NaN       NaN       NaN       NaN       NaN       NaN
# Australia  Women       NaN       NaN       NaN       NaN       NaN       NaN
# Austria      Men      80.6      79.6      79.7      79.2      79.9      79.6
# Austria    Women      52.9      52.4      52.6      52.0      52.1      52.1
# Belgium      Men      67.9      67.4      68.1      69.0      68.6      70.7
#
#            2001_fte  2002_fte  2003_fte    ...     2007_fte  2008_fte  \
# Country                                    ...
# Australia      80.3      80.2      80.5    ...         82.3      82.3
# Australia      47.9      48.0      48.7    ...         51.8      52.4
# Austria        78.4      78.1      77.9    ...         82.4      82.0
# Austria        51.9      52.6      52.7    ...         53.3      54.1
# Belgium        70.1      69.7      68.4    ...         69.7      69.0
#
# ...

# %%
#using matplotlib package for better visual

import matplotlib.pyplot as plt 
###Scatter plots with matplotlib
# %matplotlib inline  
###If not defined the graph won't be visible
plt.plot(fte['Sex'], fte['2016_fte'],'ro', color='orange')

# %% [markdown]
# It is clearly seen from above graph that Men fulltime employment rate is higher than Women.

# %%
# Gender wage gap dataset
import matplotlib.pyplot as plt

plt.style.use('fivethirtyeight') 
gwg=pd.read_csv("My datasets/Gender wage gap.csv")

gwg.head()
# Out:
#      Country  2000  2001  2002  2003  2004  2005  2006  2007  2008  2009  \
# 0  Australia  17.2  14.3  15.0  13.0  14.4  15.8  16.7  15.4  11.9  16.4
# 1    Austria  23.1  22.8  24.5  21.1  22.4  22.0  21.9  21.6  20.9  19.4
# 2    Belgium  13.6  13.2  11.6  15.2  11.8  11.5  10.3   9.9   8.9   7.5
# 3     Canada  23.9  24.3  24.0  22.5  22.7  21.3  21.1  20.8  20.5  20.1
# 4      Chile   6.1   NaN   NaN   1.7   NaN   NaN   5.6   NaN   NaN   9.1
#
#    2010  2011  2012  2013  2014  2015  2016
# 0  14.0  16.0  13.8  18.0  15.4  13.0  14.3
# 1  19.2  18.6  18.2  18.1  17.7  17.0   NaN
# 2   7.0   5.8   6.4   5.9   3.3   4.7   NaN
# 3  19.0  19.2  19.5  19.3  19.2  18.6  18.2
# 4   NaN  16.0   NaN  10.7   NaN  21.1   NaN

# %%
from matplotlib.pyplot import figure # for changing the size of graph as it was overlapping

figure(num=None, figsize=(10, 5), dpi=80, facecolor='w', edgecolor='k')

#DEMO-taking few rows for better visual 
gwg1=gwg.head(7) 

plt.plot(gwg1['Country'],gwg1['2015'])
plt.ylabel('Gender Wage Gap')

#Highestwage gap from this is seen in Chile and lowest in Belgium
# Out:
# Text(0,0.5,'Gender Wage Gap')

# %%
# Inequality dataset

import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

inequality=pd.read_csv("My datasets/Gender_inequality.csv",index_col='GII Rank')
inequality.head()
# Out:
#               Country  Gender Inequality Index (GII)  \
# GII Rank
# 1              Norway                          0.067
# 2           Australia                          0.110
# 3         Switzerland                          0.028
# 4             Denmark                          0.048
# 5         Netherlands                          0.062
#
#           Maternal Mortality Ratio  Adolescent Birth Rate  \
# GII Rank
# 1                              4.0                    7.8
# 2                              6.0                   12.1
# 3                              6.0                    1.9
# 4                              5.0                    5.1
# 5                              6.0                    6.2
#
#           Percent Representation in Parliament  \
# GII Rank
# 1                                         39.6
# 2                                         30.5
# 3                                         28.5
# 4                                         38.0
# ...

# %%
from matplotlib.pyplot import figure

plt.style.use('ggplot')
figure(num=None, figsize=(11, 5), dpi=80, facecolor='w', edgecolor='k')

in1=inequality.head(10)

plt.plot(in1['Country'],in1['Percent Representation in Parliament'])

# %%
in1=inequality.head(10)
figure(num=None, figsize=(20, 5), dpi=80, facecolor='w', edgecolor='k')

plt.bar(in1['Country'],in1['Population with Secondary Education (Female)'],align='center',color='yellowgreen')

#example-united states is having low % in parliament for women but has alomost 95% educated women->gender inequality
# Out:
# <BarContainer object of 10 artists>

# %%
plt.pie(in1['Labour Force Participation Rate (Female)'],labels=['Norway','Australia','Switzerland','Denmark','Netherlands','Germany',
                                                               'Ireland','US','Canada','NZ'],autopct='%.2f',radius=1.5,startangle=90)
#the values inside chart indicates the fraction of that part in whole pie chart
#almost every country(from 1st 10 selected) has about similar ratio
# Out:
# ([<matplotlib.patches.Wedge at 0x7ff96c2f0b00>,
# ...
#  [Text(-0.532051,1.56186,'Norway'),
#   Text(-1.36301,0.929896,'Australia'),
#   Text(-1.64808,-0.0796355,'Switzerland'),
#   Text(-1.26757,-1.0563,'Denmark'),
#   Text(-0.403922,-1.5998,'Netherlands'),
#   Text(0.57209,-1.54765,'Germany'),
#   Text(1.3192,-0.991061,'Ireland'),
#   Text(1.64728,-0.0946623,'US'),
#   Text(1.38458,0.897466,'Canada'),
#   Text(0.538749,1.55957,'NZ')],
#  [Text(-0.29021,0.851926,'10.45'),
#   Text(-0.743459,0.507216,'10.04'),
#   Text(-0.898951,-0.0434375,'10.55'),
#   Text(-0.691402,-0.576163,'10.02'),
#   Text(-0.220321,-0.872616,'9.99'),
#   Text(0.312049,-0.844171,'9.15'),
#   Text(0.719565,-0.540579,'9.07'),
#   Text(0.898518,-0.051634,'9.61'),
#   Text(0.755224,0.489527,'10.52'),
#   Text(0.293863,0.850673,'10.59')])

# %% [markdown]
# Thus, this were the visualization of some of the datasets which were described in the earlier step.
